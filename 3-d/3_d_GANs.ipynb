# %%
# %pip install torchvision matplotlib tqdm
# Out:
# Requirement already satisfied: torchvision in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (0.18.1)
# Requirement already satisfied: matplotlib in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (3.5.2)
# Requirement already satisfied: tqdm in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (4.66.4)
# Requirement already satisfied: torch==2.3.1 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torchvision) (2.3.1)
# Requirement already satisfied: numpy in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: sympy in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torch==2.3.1->torchvision) (1.12.1)
# Requirement already satisfied: filelock in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torch==2.3.1->torchvision) (3.15.4)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torch==2.3.1->torchvision) (2021.4.0)
# Requirement already satisfied: fsspec in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torch==2.3.1->torchvision) (2022.10.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torch==2.3.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torch==2.3.1->torchvision) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from torch==2.3.1->torchvision) (3.0.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: colorama in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from tqdm) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: tbb==2021.* in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.1->torchvision) (2021.13.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch==2.3.1->torchvision) (2021.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from jinja2->torch==2.3.1->torchvision) (2.1.1)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\giuli\miniconda3\envs\bima\lib\site-packages (from sympy->torch==2.3.1->torchvision) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

import torchvision.transforms as transforms
import torchvision.utils
from torchvision.utils import make_grid

import torchvision.datasets

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,6)

from tqdm import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Introduction to Generative Adversarial Networks (GANs)
#
# In this notebook you will build a GAN from scratch, grossly following the DCGAN architecture.
#
# **Goals:**
#
#
# 1.   Build a GAN arhictecture from scratch
# 2.   Write the GAN loss function and train GAN from scratch
# 3.   Have experience with some of the instability problems inherent with training GANs.
# 4.   [Bonus] Extend the unconditional GAN into a conditional GAN.

# %% [markdown]
# ## 1. Getting Started
#
# We will work with the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset. It contains 60,000 images size 28x28 of handwritten digits, from 0 to 9.

# %% [markdown]
# ## 1. Dataloading
#
# ### 1.1 Define some hyperparameters and transforms

# %%
batch_size = 128 # Images per batch

# Resize to 32x32 for easier upsampling/downsampling
mytransform = transforms.Compose([transforms.Resize(32),
                                  transforms.ToTensor(),
                                 transforms.Normalize((.5,), (.5,))]) # normalize between [-1, 1] with tanh activation

mnist_train = torchvision.datasets.MNIST(root='.', download=True, transform=mytransform)

# %%
dataloader = DataLoader(dataset=mnist_train,
                         batch_size=batch_size,
                         shuffle=True)

# %%
# plot some images
real_batch, real_labels = next(iter(dataloader))

# %%
plt.imshow(transforms.ToPILImage()(make_grid(real_batch)))

# %% [markdown]
# ## 2. Model Architecture
#
# We will follow the general architecture of a DCGAN - or deep convolutional GAN. This [influential paper](https://arxiv.org/pdf/1511.06434v2.pdf) produced much of the foundation for modern GANs and how to train them.
#
# (GANs are notoriously **hard** to train, we will try to get a feeling why in this notebook.)

# %% [markdown]
# Complete the function `get_upscaling_block`. Then, use the function to define our model defined as follows:
#
# Input: Random "noise" $z$ shaped `[n_batch, n_z]`
#
# Output: Generated image size `[n_batch, 1, 32, 32]` in range [-1, 1]
#
# 1. Reshape z into `[n_batch, n_z, 1, 1]` to make it into an "image"
# 2. First upscaling block $\rightarrow$ `[n_batch, ngf*4, 4, 4]`
# 3. Second upscaling block $\rightarrow$ `[n_batch, ngf*2, 8, 8]`
# 4. Third upscaling block $\rightarrow$ `[n_batch, ngf, 16, 16]`
# 5. Fourth (and last) upscaling block $\rightarrow$ `[n_batch, 1, 32, 32]`

# %% [markdown]
# ## 2.1. The Generator
#
#
#
# The generator performs subsequent upsampling blocks, transforming a latent vector shaped [batch_size, latent_size] into an image (values in [-1, 1]).
#
# The generator block will consists of:
# - Transpose Convolution
# - Batch Norm
# - ReLU

# %%
def get_upscaling_block(channels_in, channels_out, kernel, stride, padding, last_layer=False):
    '''
    Each transpose conv will be followed by BatchNorm and ReLU,
    except the last block (which is only followed by tanh)
    '''
    if last_layer:
      
        return nn.Sequential(
            nn.ConvTranspose2d(channels_in, channels_out, kernel, stride, padding, bias=False),
            nn.Tanh()
        )
    else:
       
        return nn.Sequential(
            nn.ConvTranspose2d(channels_in, channels_out, kernel, stride, padding, bias=False),
            nn.BatchNorm2d(num_features = channels_out),
            nn.ReLU(),
        )


class Generator(nn.Module):
    def __init__(self, nz, ngf, nchannels=1):
        '''
        nz: The latent size (100 in our case)
        ngf: The channel-size before the last layer (32 our case)
        '''
        super(Generator, self).__init__()

        self.main = nn.Sequential(
            get_upscaling_block(nz, ngf*4, 4, 1, 0), 
            get_upscaling_block(ngf*4, ngf*2, 4, 2, 1), 
            get_upscaling_block(ngf*2, ngf, 4, 2, 1), 
            get_upscaling_block(ngf, nchannels, 4, 2, 1, last_layer=True)
        )
    
        """self.conv1 = get_upscaling_block(nz, ngf*4, 4, 1, 0, False) #128 filters ngf*8
        self.conv2 = get_upscaling_block(ngf*4, ngf*2, 4, 2, 1, False) #64 filters ngf*4
        self.conv3 = get_upscaling_block(ngf*2, ngf, 4, 2, 1, False) #32 filters ngf*2
        self.conv4 = get_upscaling_block(ngf, 1, 4, 2, 1, True)

        self.model = nn.Sequential(
            self.conv1, self.conv2, self.conv3, self.conv4 #not right way
        )"""


    def forward(self, z):
        x = z.unsqueeze(2).unsqueeze(2) # give spatial dimensions to z
        return self.main(x)

# %% [markdown]
# ### 2.1.3. Sanity Tests

# %%
nz = 100
z = torch.randn(batch_size, nz)

# %%
G = Generator(nz=nz, ngf=32)

assert G(z).shape == (batch_size, 1, 32, 32)

# %%
# visualize the output - at first it should just look like random noise!!
x_fake = G(z)
plt.imshow(transforms.ToPILImage()(make_grid(x_fake, nrow=8)))

# %% [markdown]
# ## 2.2. The discriminator
#
# The discriminator will be a mirror image of the generator.

# %% [markdown]
# The discriminator will also use a fully convolutional architecutre, with each block consisting of:
# - Conv layer
# - BatchNorm
# - ReLU
#
# Complete the function `get_downscaling_block` and then use it to define the following architecture for the discriminator:
#
# Input: Image shaped `[n_batch, 1, 32, 32]` (in [-1, 1])
# Output: Discriminator scores `[n_batch, 1]` in range [0, 1]
#
# 1. First downscaling block $\rightarrow$ `[n_batch, ndf, 16, 16]`
# 2. Second downscaling block $\rightarrow$ `[n_batch, ndf*2, 8, 8]`
# 3. Third downscaling block $\rightarrow$ `[n_batch, ndf*4, 4, 4]`
# 4. Last downscaling block $\rightarrow$ `[n_batch, 1]`

# %%
def get_downscaling_block(channels_in, channels_out, kernel, stride, padding, use_batch_norm=True, is_last=False):

    """if is_last: 
        return nn.Conv2d(channels_in, channels_out, kernel, stride, padding, bias=False)
    else: 
        return nn.Sequential(
            nn.Conv2d(channels_in, channels_out, kernel, stride, padding, bias=False), 
            nn.BatchNorm2d(channels_out), 
            nn.LeakyReLU(0.2)
        )"""
    if is_last:
        return nn.Sequential(
            nn.Conv2d(channels_in, channels_out, kernel, stride, padding, bias=False),
            nn.Sigmoid())


    elif not use_batch_norm:
       
        return nn.Sequential(
            nn.Conv2d(channels_in, channels_out, kernel, stride, padding, bias=False),
            nn.LeakyReLU(0.2))

    else:
        
        return nn.Sequential(
            nn.Conv2d(channels_in, channels_out, kernel, stride, padding, bias=False),
            nn.BatchNorm2d(channels_out), nn.LeakyReLU(0.2))



class Discriminator(nn.Module):
    def __init__(self, ndf, nchannels=1):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            get_downscaling_block(1, ndf, 4, 2, 1),
            get_downscaling_block(ndf, ndf*2, 4, 2, 1), 
            get_downscaling_block(ndf*2, ndf*4, 4, 2, 1), 
            get_downscaling_block(ndf*4, 1, 4, 1, 0, is_last=True)
        )
      

    def forward(self, x):
        return self.main(x).squeeze(1).squeeze(1) # remove spatial dimensions

# %% [markdown]
# ### 2.2.3 Sanity Checking

# %%
real_batch, real_labels = next(iter(dataloader))

# %%
D = Discriminator(ndf=32, nchannels=1)
print(real_batch[0].shape)
print(D(real_batch).shape)

assert D(real_batch).shape == (real_batch.shape[0], 1)
# Out:
# torch.Size([1, 32, 32])
# torch.Size([128, 1])

# %% [markdown]
# # 3. Training
#
# ## 3.1 Loss
# The essential thing to remember is that the logistic and the non-saturating logistic GAN losses can be written exclusively using the [binary cross entropy loss](https://pytorch.org/docs/stable/generated/torch.nn.BCELoss.html). Our GAN loss will be defined ONLY using the following criterion:

# %%
criterion = nn.BCELoss() # we will build off of this to make our final GAN loss!

# %% [markdown]
# ## 3.2 Helper functions
#
# We will need a few helper functions.
# 1. First, we need to continuously sample z from a Gaussian distribution.
# 2. Secondly, we need to make our "ground-truth" labels when using the BCE loss. This should output vectors of either 0s or 1s.

# %%
def sample_z(batch_size, nz):
    return torch.randn(batch_size, nz, device=device)

# this is for the real ground-truth label
def get_labels_one(batch_size):
    r = torch.ones(batch_size, 1)
    return r.to(device)

# this is for the generated ground-truth label
def get_labels_zero(batch_size):
    r = torch.zeros(batch_size, 1)
    return r.to(device)


# To initialize the weights of a GAN, the DCGAN paper found that best results are obtained
# with Gaussian initialization with mean=0; std=0.02
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# for visualization
to_pil = transforms.ToPILImage()
renorm = transforms.Normalize((-1.), (2.))

# %% [markdown]
# ## 3.3 Creating the optimizers and hyperparameters
#
# The original DCGAN paper shows that Adam works well in the generator and the discriminator with a learning rate of 0.0002 and Beta1 = 0.5.
#
# Define your optimizers

# %%
nz = 100
ngf = 32
ndf = 32

nchannels= 1
lr_d = 0.001
lr_g = 0.001 #0.00005
beta1= 0.5
display_freq = 400

nb_epochs = 5

netG = Generator(nz, ngf, nchannels).to(device)
netD = Discriminator(ndf, nchannels).to(device)

netD.apply(weights_init)
netG.apply(weights_init)

g_opt = torch.optim.Adam(netG.parameters(), lr=lr_g, betas=(beta1, 0.999))
d_opt = torch.optim.Adam(netD.parameters(), lr=lr_d, betas=(beta1, 0.999))

# %% [markdown]
# ## 3.3 Training!
#
# Now for the fun part, training!
# Training a GAN consists in making an update to the discriminator, then the generator.
# Training a GAN requires BABYSITTING!! Remember that many things can go wrong when training a GAN:
# - The discriminator is too strong for the generator - the generator cannot improve.
# - The generator easily fools the discriminator - cannot learn.
# - Mode collapse - generator is not capable of generating diverse images.

# %%
g_losses = []
d_losses = []

yhat_real = []
yhat_fake = []


j = 0


#z_test = sample_z(64, nz) # we generate the noise only once for testing
z_test = sample_z(128, nz)


for epoch in range(nb_epochs):

    # train
    pbar = tqdm(enumerate(dataloader))
    for i, batch in pbar:
        im, _ = batch # we don't care about the label for unconditional generation
        im = im.to(device)

        cur_batch_size = im.shape[0]


        # 1. sample a z vector
        sample = sample_z(cur_batch_size, nz).to(device)
        sample.requires_grad = True


        # 2. Generate a fake image
        fake_image = netG(sample)

        # 3. Classify real image with D
        yhat_real = netD(im)

        # 4. Classify fake image with D
        yhat_fake = netD(fake_image)

        ###
        ### Discriminator
        ###

        label_real =  get_labels_one(cur_batch_size)
        #print(yhat_real, '\n')
        err_real = criterion(yhat_real, label_real)

        label_fake =  get_labels_zero(cur_batch_size)
        err_fake = criterion(yhat_fake, label_fake)

        #print(f"yhat_real {yhat_real[0]} yhat_fake {yhat_fake[0]}")

        d_loss = err_fake + err_real #     YOUR CODE HERE
        d_opt.zero_grad()
        d_loss.backward(retain_graph=True) # we need to retain graph=True to be able to calculate the gradient in the g backprop
        d_opt.step()


        ###
        ### Generator
        ###

        label_real = get_labels_one(cur_batch_size)

        # 4. Classify fake image with D
        yhat_fake = netD(fake_image)

        g_loss = criterion(yhat_fake, label_real) #      YOUR CODE HERE
        g_opt.zero_grad()
        g_loss.backward()
        g_opt.step()

        


        # Save Metrics

        d_losses.append(d_loss.item())
        g_losses.append(g_loss.item())

        avg_real_score = yhat_real.mean().item()
        avg_fake_score = yhat_fake.mean().item()


        pbar.set_description(f"it: {j}; g_loss: {g_loss}; d_loss: {d_loss}; avg_real_score: {avg_real_score}; avg_fake_score: {avg_fake_score}")

        #d_opt.zero_grad()
        #g_opt.zero_grad()
        if i % display_freq == 0:

            fake_im = netG(z_test)

            un_norm = renorm(fake_im) # for visualization

            grid = torchvision.utils.make_grid(un_norm, nrow=8)
            pil_grid = to_pil(grid)

            print("generated images")
            plt.imshow(pil_grid)
            plt.show()

            plt.plot(range(len(g_losses)), g_losses, label='g loss')
            plt.plot(range(len(g_losses)), d_losses, label='d loss')

            plt.legend()
            plt.show()

        j += 1
# Out:
# it: 0; g_loss: 2.8731985092163086; d_loss: 1.249182939529419; avg_real_score: 0.5606223940849304; avg_fake_score: 0.06662338227033615: : 0it [00:00, ?it/s]
# generated images
# it: 400; g_loss: 1.6459909677505493; d_loss: 0.3878854513168335; avg_real_score: 0.7712975740432739; avg_fake_score: 0.208546444773674: : 400it [02:54,  1.70it/s]
# generated images
# it: 468; g_loss: 1.4759470224380493; d_loss: 0.8424960374832153; avg_real_score: 0.6117962598800659; avg_fake_score: 0.2582619786262512: : 469it [03:27,  2.26it/s]
# it: 469; g_loss: 1.435383677482605; d_loss: 0.7355728149414062; avg_real_score: 0.6951331496238708; avg_fake_score: 0.2629671096801758: : 0it [00:00, ?it/s]
# generated images
# it: 869; g_loss: 3.041830539703369; d_loss: 0.5624302625656128; avg_real_score: 0.8883253931999207; avg_fake_score: 0.056334417313337326: : 400it [03:00,  2.52it/s]
# generated images
# it: 937; g_loss: 2.03857159614563; d_loss: 0.4412248730659485; avg_real_score: 0.770573079586029; avg_fake_score: 0.15185967087745667: : 469it [03:28,  2.25it/s]
# it: 938; g_loss: 1.7547314167022705; d_loss: 0.5160099267959595; avg_real_score: 0.7930699586868286; avg_fake_score: 0.20132221281528473: : 0it [00:00, ?it/s]
# generated images
# it: 1338; g_loss: 2.7805888652801514; d_loss: 0.4535388648509979; avg_real_score: 0.8515896201133728; avg_fake_score: 0.07846235483884811: : 400it [03:06,  2.03it/s]
# generated images
# it: 1406; g_loss: 1.3699525594711304; d_loss: 0.6669456958770752; avg_real_score: 0.5935629606246948; avg_fake_score: 0.2934718430042267: : 469it [03:38,  2.15it/s]
# it: 1407; g_loss: 3.2924575805664062; d_loss: 0.6344137191772461; avg_real_score: 0.9205582737922668; avg_fake_score: 0.04790230840444565: : 0it [00:00, ?it/s]
# generated images
# it: 1807; g_loss: 0.9831883907318115; d_loss: 0.7409398555755615; avg_real_score: 0.5667542219161987; avg_fake_score: 0.43296265602111816: : 400it [02:44,  2.71it/s]
# generated images
# it: 1875; g_loss: 2.405113935470581; d_loss: 0.3440930247306824; avg_real_score: 0.7672780156135559; avg_fake_score: 0.12185204774141312: : 469it [03:11,  2.45it/s]
# it: 1876; g_loss: 2.7742652893066406; d_loss: 0.3293355107307434; avg_real_score: 0.9172084331512451; avg_fake_score: 0.08154863864183426: : 0it [00:00, ?it/s]
# generated images
# it: 2276; g_loss: 1.6522727012634277; d_loss: 0.445743203163147; avg_real_score: 0.7249234318733215; avg_fake_score: 0.23751454055309296: : 400it [02:35,  2.56it/s]
# generated images
# it: 2344; g_loss: 2.8268909454345703; d_loss: 0.730396032333374; avg_real_score: 0.9272603988647461; avg_fake_score: 0.08181833475828171: : 469it [03:02,  2.56it/s]

# %% [markdown]
# # 4. Conditional GANs [BONUS]
#
# A simple way to improve training performance and obtain control of the generation is to provide extra information into the Generator and the Discriminator, known as **Conditional GANs**. In this case, we will provide the class label (digit number of MNIST) into both the generator and the discriminator. This will help both of the networks.

# %% [markdown]
# ## 4.1 Conditional Generator and Discriminator
#
# Complete the ConditionalDiscriminator and ConditionalGenerator classes using your GAN building blocks (`get_upsampling_block` and `get_downsampling_block` functions).

# %% [markdown]
# ### 4.1.1 Generator

# %%
# GENERATOR

'''
The conditional generator needs the label information as well as the latent vector. We will combine the latent vector and the class information in the following way:

- The class information for the generator will be represented as a one-hot vector sized `[batch_size, 10]` (since there are 10 classes in MNIST)
- The latent vector for the generator will still be sized `[batch_size, nz]`

1. Transform both of these modalities into 'images' (by adding dimensions)
2. Like before, apply the first upscaling block to both of these 'images'. We will now have 2 separate blocks sized

'''

class ConditionalGenerator(nn.Module):
    def __init__(self, nz, nc, ngf, nchannels=1):
        super().__init__()

        self.upscaling_z = get_upscaling_block(nz, ngf*8, 4, 1, 0)
        self.upscaling_c = get_upscaling_block(nc, ngf*8, 4, 1, 0)

      
        self.rest_model = nn.Sequential(
            get_upscaling_block(ngf*16, ngf*4, 4, 2, 1), 
            get_upscaling_block(ngf*4, ngf*2, 4, 2, 1), 
            get_upscaling_block(ngf*2, ngf, 4, 2, 1), 
            get_upscaling_block(ngf, nchannels, 4, 2, 1, last_layer=True)
        )

        ###################

    def forward(self, x, y):
        x = x.unsqueeze(2).unsqueeze(2)
        y = y.unsqueeze(2).unsqueeze(2)

        x = self.upscaling_z(x)
        y = self.upscaling_c(y)

        x = torch.cat([x, y], dim=1)

        return self.rest_model(x)

# %% [markdown]
# ### 4.1.2 Discriminator

# %%
# Discriminator

'''
The conditional discriminator needs the label information as well as the latent vector. We will combine the latent vector and the class information in the following way:

- The class information for the discriminator will be represented as a one-hot vector sized `[batch_size, 10]` (since there are 10 classes in MNIST)
- The latent vector for the generator will still be sized `[batch_size, nz]`

1. Transform both of these modalities into 'images' (by adding dimensions)
2. Like before, apply the first upscaling block to both of these 'images'. We will now have 2 separate blocks sized

'''

class ConditionalDiscriminator(nn.Module):
    def __init__(self, ndf, nc, nchannels=1):
        super().__init__()
        self.downscale_x = get_downscaling_block(nchannels, ndf*2, 4, 2, 1, use_batch_norm=False)
        self.downscale_y = get_downscaling_block(nc, ndf*2, 4, 2, 1, use_batch_norm=False)

     

        self.rest = nn.Sequential(
           get_downscaling_block(ndf * 4, ndf * 4, 4, 2, 1),
            get_downscaling_block(ndf * 4, ndf * 8, 4, 2, 1),
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    

    def forward(self, x, y):
        y = y.unsqueeze(2).unsqueeze(3).expand(-1, -1, x.size(2), x.size(3))

        x = self.downscale_x(x)
        y = self.downscale_y(y)

        xy = torch.cat([x, y], dim=1)
        
        #return self.rest(xy).view(x.size(0), -1)
        
        return self.rest(xy).squeeze(1).squeeze(1) # remove spatial dimensions

# %% [markdown]
# ### 4.1.3 Sanity Checks

# %%
# CONDITIONAL GENERATOR SANITY CHECKING

z = torch.randn(batch_size, nz)
y = F.one_hot(real_labels).float()

cG = ConditionalGenerator(nz=nz, ngf=16, nc=10)
x_fake = cG(z, y)
plt.imshow(transforms.ToPILImage()(make_grid(x_fake, nrow=8)))

# %%
# Conditional Discriminator Sanity Checking

cD = ConditionalDiscriminator(ndf=32, nc=10, nchannels=1)
assert cD(real_batch, F.one_hot(real_labels).float()).shape == (real_batch.shape[0], 1)
#print("Sanity check passed. Output shape:", output.shape)

# %% [markdown]
# ## 4.2 Training

# %%
nz = 100
ndf = 32
ngf = 32
nchannels= 1
lr_d = 0.0002
lr_g = 0.0005
beta1= 0.5
display_freq = 200

nc= 10

netD = ConditionalDiscriminator(ndf, nc, nchannels=1).to(device)
netG = ConditionalGenerator(nz, nc, ngf).to(device)

netG.apply(weights_init)
netD.apply(weights_init)

g_opt = torch.optim.Adam(netG.parameters(), lr=lr_g, betas=(beta1, 0.999))
d_opt = torch.optim.Adam(netD.parameters(), lr=lr_d, betas=(beta1, 0.999))

# %%
nb_epochs = 5

g_losses = []
d_losses = []

j = 0

z_test = sample_z(100, nz)  # we generate the noise only once for testing


for epoch in range(nb_epochs):

    pbar = tqdm(enumerate(dataloader))
    for i, batch in pbar:
        im, labels = batch
        im = im.to(device)


        y = F.one_hot(labels).float().to(device)

        cur_batch_size = im.shape[0]


        # 1. sample a z vector
        z = sample_z(cur_batch_size, nz).to(device)

        # 2. Generate a fake image
        fake_im = netG(z, y)

        # 3. Classify real image with D
        yhat_real = netD(im, y)

        # 4. Classify fake image with D
        yhat_fake = netD(fake_im.detach(), y)

        #labels 
        real_labels = torch.ones(cur_batch_size, 1).to(device)
        fake_labels = torch.zeros(cur_batch_size, 1).to(device)


        ###
        ### Discriminator
        ###
        d_loss_real = criterion(yhat_real, real_labels)
        d_loss_fake = criterion(yhat_fake, fake_labels)
        d_loss = d_loss_real + d_loss_fake# YOUR CODE HERE
        d_opt.zero_grad()
        d_loss.backward(retain_graph=True) # we need to retain graph=True to be able to calculate the gradient in the g backprop
        d_opt.step()


        ###
        ### Generator
        ###

        #Re-classify the fake images using updated discriminator
        yhat_fake = netD(fake_im, y)

        g_loss = criterion(yhat_fake, real_labels)# YOUR CODE HERE
        g_opt.zero_grad()
        g_loss.backward()
        g_opt.step()


        # Save Metrics

        d_losses.append(d_loss.item())
        g_losses.append(g_loss.item())

        avg_real_score = yhat_real.mean().item()
        avg_fake_score = yhat_fake.mean().item()

        pbar.set_description(f"it: {j}; g_loss: {g_loss}; d_loss: {d_loss}; avg_real_score: {avg_real_score}; avg_fake_score: {avg_fake_score}")

        if i % display_freq == 0:
            labels = torch.arange(0, 10).expand(size=(10, 10)).flatten().to(device)
            y = F.one_hot(labels).float().to(device)
            fake_im = netG(z_test, y)

            un_norm = renorm(fake_im) # for visualization

            grid = torchvision.utils.make_grid(un_norm, nrow=10)
            pil_grid = to_pil(grid)

            plt.imshow(pil_grid)
            plt.show()


            plt.plot(range(len(g_losses)), g_losses, label='g loss')
            plt.plot(range(len(g_losses)), d_losses, label='d loss')

            plt.legend()
            plt.show()

        j += 1
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 11>()
#      41 ###
#      42 ### Discriminator
#      43 ###
#      44 d_loss_real = criterion(yhat_real, real_labels)
# ---> 45 d_loss_fake = criterion(yhat_fake, fake_labels)
#      46 d_loss = d_loss_real + d_loss_fake# YOUR CODE HERE
#      47 d_opt.zero_grad()
#
# File c:\Users\giuli\miniconda3\envs\bima\lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\giuli\miniconda3\envs\bima\lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\giuli\miniconda3\envs\bima\lib\site-packages\torch\nn\modules\loss.py:618, in BCELoss.forward(self, input, target)
#     617 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 618     return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#
# File c:\Users\giuli\miniconda3\envs\bima\lib\site-packages\torch\nn\functional.py:3145, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3143     reduction_enum = _Reduction.get_enum(reduction)
#    3144 if target.size() != input.size():
# -> 3145     raise ValueError(
#    3146         "Using a target size ({}) that is different to the input size ({}) is deprecated. "
#    3147         "Please ensure they have the same size.".format(target.size(), input.size())
#    3148     )
#    3150 if weight is not None:
#    3151     new_size = _infer_size(target.size(), weight.size())
#
# ValueError: Using a target size (torch.Size([128, 1])) that is different to the input size (torch.Size([128, 5, 5])) is deprecated. Please ensure they have the same size.

# %% [markdown]
# ## 4.2 Testing
# Visualization of the impact of z on generation. All digits in the same column have the same noise vector z.

# %%
n_ex = 15
n_classes = 10

z = sample_z(n_ex, nz).repeat(n_classes, 1) #.expand(10, nz)

netG.eval()

labels = torch.arange(n_classes).unsqueeze(0).reshape(-1, 1).repeat(1, n_ex).flatten().to(device)

ys = F.one_hot(labels).float()
fake_ims = netG(z, ys)

un_norm= renorm(fake_ims) # for visualization
grid = torchvision.utils.make_grid(un_norm, nrow=n_ex)
pil_grid = to_pil(grid)

plt.imshow(pil_grid)
plt.show()
